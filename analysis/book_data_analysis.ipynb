# %%
import findspark

# %%
findspark.init()

# %%
import pyspark

# %%
from pyspark.sql import SQLContext
from pyspark import SparkContext
from pyspark import SparkConf
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import DoubleType
import functools
import pandas as pd
#pd.options.display.max_colwidth = None

# %%
book = 'hdfs://master:9000/user/practice/book_data.csv'
isbn_summary = 'hdfs://master:9000/user/practice/sbn_review.csv'

# %%
sc1 = SparkSession.builder.appName('book_data').getOrCreate()
sc2 = SparkSession.builder.appName('isbn_review').getOrCreate()

# %%
books = sc1.read.csv(book, header=True, inferSchema=True)
books.printSchema()
# Out:
# root
#  |-- main_category: string (nullable = true)
#  |-- sub_category: string (nullable = true)
#  |-- book_id: integer (nullable = true)
#  |-- book_title: string (nullable = true)
#  |-- book_author: string (nullable = true)
#  |-- publisher: string (nullable = true)
#  |-- publish_date: string (nullable = true)
#  |-- aladin_price: integer (nullable = true)
#  |-- aladin_star: double (nullable = true)
#  |-- aladin_review: integer (nullable = true)
#  |-- kyobo_price: integer (nullable = true)
#  |-- kyobo_star: double (nullable = true)
#  |-- kyobo_review: integer (nullable = true)
#  |-- yes24_price: integer (nullable = true)
#  |-- yes24_star: double (nullable = true)
#  |-- yes24_review: integer (nullable = true)
#  |-- interpark_price: integer (nullable = true)
#  |-- interpark_star: double (nullable = true)
#  |-- interpark_review: integer (nullable = true)

# %%
books.limit(10).toPandas()

# %%
isbns = sc2.read.option('multiline', True).csv(isbn_summary, header=True, inferSchema=True)
isbns.printSchema()
isbns.columns
# Out:
# root
#  |-- book_id: integer (nullable = true)
#  |-- book_isbn: string (nullable = true)
# : string (nullable = true)
# ['book_id', 'book_isbn', 'book_trailer\r']

# %%
isbns = isbns.select(col('book_id'), col('book_isbn'), col('book_trailer\r').alias('book_trailer'))

# %%
# isbns = isbns.distinct()
isbns.toPandas()

# %%
category = books.groupBy('main_category').agg(count('main_category'))
category.show(25)
# Out:
# +--------------+--------------------+
# | main_category|count(main_category)|
# +--------------+--------------------+
# |   국어/외국어|                 409|
# |      해외도서|                 350|
# |     취미/레저|                 797|
# |          유아|                 456|
# |     여행/지도|                 240|
# |          건강|                 422|
# |   학습/참고서|                 255|
# |          잡지|                  60|
# |          인문|                 656|
# |   취업/수험서|                 203|
# |     경제/경영|                 561|
# |          만화|                 852|
# |        청소년|                 591|
# |     시/에세이|                 787|
# |          소설|                 390|
# |     컴퓨터/IT|                 396|
# |          사회|                 421|
# |        어린이|                 455|
# | 예술/대중문화|                 632|
# |     역사/문화|                 137|
# |          종교|                 357|
# |가정/생활/요리|                 412|
# |     과학/공학|                 835|
# |      자기계발|                 455|
# |          사전|                 127|
# +--------------+--------------------+

# %% [markdown]
# # 모든 플랫폼 중에 최저가격 확인

# %%
books = books.withColumn("min price", least('aladin_price', 'kyobo_price', 'yes24_price', 'interpark_price'))
books.limit(10).toPandas()
# Out:
#   main_category sub_category   book_id  \
# 0      가정/생활/요리           요리  21354394
# 1      가정/생활/요리         집/살림  14518950
# 2      가정/생활/요리         집/살림  16853326
# 3      가정/생활/요리         집/살림   6860734
# 4      가정/생활/요리         집/살림  12863883
# 5      가정/생활/요리         집/살림  16290376
# 6      가정/생활/요리         집/살림  22202689
# 7      가정/생활/요리         집/살림   8843474
# 8      가정/생활/요리         집/살림   7306017
# 9      가정/생활/요리         집/살림   7361595
#
#                                book_title      book_author publisher  \
# 0                       에듀윌 제과 제빵기능사 필기끝장   오명석 장다예 박진홍 외        에듀윌
# 1                               노후주택 리모델링      전원속의 내집 편집부     주택문화사
# 2                              실내에서 이끼키우기  이선희 박웅택 정혜원 이은정       플로라
# 3                      내 손으로 직접하는 나무 가지치기              편집부       그린홈
# 4  시공사도 건축가도 안 알려주는 건축주만이 알려줄 수 있는 집짓기 진실              손창완     주택문화사
# 5                        선인장도 말려 죽이는 그대에게              송한나        책밥
# 6                                 방구석 가드닝        앤절라 S. 저드      문학수첩
# 7                                인테리어 원 북              윤소연    디자인하우스
# 8                               텃밭정원 가이드북               오도       그물코
# 9                                  정원의 발견              오경아        궁리
#
#   publish_date  aladin_price  aladin_star  aladin_review  kyobo_price  \
# 0   2022.01.09         18000         10.0              7        18000
# 1   2019.01.24         24300         10.0              1        24300
# 2   2020.10.20         14400         10.0              1        14400
# 3   2012.03.15         17100          7.5              4        17100
# 4   2017.12.06         20700         10.0              4        20700
# 5   2020.03.23         16920          9.2             12        16920
# 6   2022.03.25         12600         10.0              4        12600
# 7   2015.04.05         14400          9.0             36        14400
# 8   2013.09.10         13500          9.5              4        13500
# 9   2013.11.15         20700          8.4             11        20700
#
#    kyobo_star  kyobo_review  yes24_price  yes24_star  yes24_review  \
# 0         9.4             3        20000        10.0             6
# 1         9.8             0        27000         8.8             5
# 2         8.3             0        16000        10.0             1
# 3         9.7             1        19000         9.2             6
# 4         9.2             0        23000         8.8             4
# 5         9.2             6        18800         9.2            16
# 6        10.0             1        14000        10.0             5
# 7         9.2            20        16000         8.9            25
# 8         9.0             0        15000         8.8             4
# 9        10.0             6        23000         9.4            14
#
#    interpark_price  interpark_star  interpark_review  min price
# 0            18000            10.0                 5      18000
# 1            24300            10.0                 1      24300
# 2            14400             0.0                 0      14400
# 3            17100             8.0                 1      17100
# 4            20700             0.0                 0      20700
# 5            16920             9.1                 7      16920
# 6            12600             0.0                 0      12600
# 7            14400             9.9                15      14400
# 8            13500             9.3                 1      13500
# 9            20700             9.0                 2      20700

# %% [markdown]
# # 모든 플랫폼에서 평점평균 확인

# %%
books = books.withColumn("avg stars", (col('aladin_star')+col('kyobo_star')+col('yes24_star')+col('interpark_star'))/4)
books.limit(10).toPandas()
# Out:
#   main_category sub_category   book_id  \
# 0      가정/생활/요리           요리  21354394
# 1      가정/생활/요리         집/살림  14518950
# 2      가정/생활/요리         집/살림  16853326
# 3      가정/생활/요리         집/살림   6860734
# 4      가정/생활/요리         집/살림  12863883
# 5      가정/생활/요리         집/살림  16290376
# 6      가정/생활/요리         집/살림  22202689
# 7      가정/생활/요리         집/살림   8843474
# 8      가정/생활/요리         집/살림   7306017
# 9      가정/생활/요리         집/살림   7361595
#
#                                book_title      book_author publisher  \
# 0                       에듀윌 제과 제빵기능사 필기끝장   오명석 장다예 박진홍 외        에듀윌
# 1                               노후주택 리모델링      전원속의 내집 편집부     주택문화사
# 2                              실내에서 이끼키우기  이선희 박웅택 정혜원 이은정       플로라
# 3                      내 손으로 직접하는 나무 가지치기              편집부       그린홈
# 4  시공사도 건축가도 안 알려주는 건축주만이 알려줄 수 있는 집짓기 진실              손창완     주택문화사
# 5                        선인장도 말려 죽이는 그대에게              송한나        책밥
# 6                                 방구석 가드닝        앤절라 S. 저드      문학수첩
# 7                                인테리어 원 북              윤소연    디자인하우스
# 8                               텃밭정원 가이드북               오도       그물코
# 9                                  정원의 발견              오경아        궁리
#
#   publish_date  aladin_price  aladin_star  aladin_review  ...  kyobo_star  \
# 0   2022.01.09         18000         10.0              7  ...         9.4
# 1   2019.01.24         24300         10.0              1  ...         9.8
# 2   2020.10.20         14400         10.0              1  ...         8.3
# 3   2012.03.15         17100          7.5              4  ...         9.7
# 4   2017.12.06         20700         10.0              4  ...         9.2
# 5   2020.03.23         16920          9.2             12  ...         9.2
# 6   2022.03.25         12600         10.0              4  ...        10.0
# 7   2015.04.05         14400          9.0             36  ...         9.2
# 8   2013.09.10         13500          9.5              4  ...         9.0
# 9   2013.11.15         20700          8.4             11  ...        10.0
#
#    kyobo_review  yes24_price  yes24_star  yes24_review  interpark_price  \
# 0             3        20000        10.0             6            18000
# 1             0        27000         8.8             5            24300
# 2             0        16000        10.0             1            14400
# 3             1        19000         9.2             6            17100
# 4             0        23000         8.8             4            20700
# 5             6        18800         9.2            16            16920
# 6             1        14000        10.0             5            12600
# 7            20        16000         8.9            25            14400
# 8             0        15000         8.8             4            13500
# 9             6        23000         9.4            14            20700
#
#    interpark_star  interpark_review  min price  avg stars
# 0            10.0                 5      18000      9.850
# 1            10.0                 1      24300      9.650
# 2             0.0                 0      14400      7.075
# 3             8.0                 1      17100      8.600
# 4             0.0                 0      20700      7.000
# 5             9.1                 7      16920      9.175
# 6             0.0                 0      12600      7.500
# 7             9.9                15      14400      9.250
# 8             9.3                 1      13500      9.150
# 9             9.0                 2      20700      9.200
#
# [10 rows x 21 columns]

# %% [markdown]
# # 모든 플랫폼에서 리뷰 총 개수

# %%
books = books.withColumn("num of reviews", col('aladin_review')+col('kyobo_review')+col('yes24_review')+col('interpark_review'))
books.limit(10).toPandas()
# Out:
#   main_category sub_category   book_id  \
# 0      가정/생활/요리           요리  21354394
# 1      가정/생활/요리         집/살림  14518950
# 2      가정/생활/요리         집/살림  16853326
# 3      가정/생활/요리         집/살림   6860734
# 4      가정/생활/요리         집/살림  12863883
# 5      가정/생활/요리         집/살림  16290376
# 6      가정/생활/요리         집/살림  22202689
# 7      가정/생활/요리         집/살림   8843474
# 8      가정/생활/요리         집/살림   7306017
# 9      가정/생활/요리         집/살림   7361595
#
#                                book_title      book_author publisher  \
# 0                       에듀윌 제과 제빵기능사 필기끝장   오명석 장다예 박진홍 외        에듀윌
# 1                               노후주택 리모델링      전원속의 내집 편집부     주택문화사
# 2                              실내에서 이끼키우기  이선희 박웅택 정혜원 이은정       플로라
# 3                      내 손으로 직접하는 나무 가지치기              편집부       그린홈
# 4  시공사도 건축가도 안 알려주는 건축주만이 알려줄 수 있는 집짓기 진실              손창완     주택문화사
# 5                        선인장도 말려 죽이는 그대에게              송한나        책밥
# 6                                 방구석 가드닝        앤절라 S. 저드      문학수첩
# 7                                인테리어 원 북              윤소연    디자인하우스
# 8                               텃밭정원 가이드북               오도       그물코
# 9                                  정원의 발견              오경아        궁리
#
#   publish_date  aladin_price  aladin_star  aladin_review  ...  kyobo_review  \
# 0   2022.01.09         18000         10.0              7  ...             3
# 1   2019.01.24         24300         10.0              1  ...             0
# 2   2020.10.20         14400         10.0              1  ...             0
# 3   2012.03.15         17100          7.5              4  ...             1
# 4   2017.12.06         20700         10.0              4  ...             0
# 5   2020.03.23         16920          9.2             12  ...             6
# 6   2022.03.25         12600         10.0              4  ...             1
# 7   2015.04.05         14400          9.0             36  ...            20
# 8   2013.09.10         13500          9.5              4  ...             0
# 9   2013.11.15         20700          8.4             11  ...             6
#
#    yes24_price  yes24_star  yes24_review  interpark_price  interpark_star  \
# 0        20000        10.0             6            18000            10.0
# 1        27000         8.8             5            24300            10.0
# 2        16000        10.0             1            14400             0.0
# 3        19000         9.2             6            17100             8.0
# 4        23000         8.8             4            20700             0.0
# 5        18800         9.2            16            16920             9.1
# 6        14000        10.0             5            12600             0.0
# 7        16000         8.9            25            14400             9.9
# 8        15000         8.8             4            13500             9.3
# 9        23000         9.4            14            20700             9.0
#
#    interpark_review  min price  avg stars  num of reviews
# 0                 5      18000      9.850              21
# 1                 1      24300      9.650               7
# 2                 0      14400      7.075               2
# 3                 1      17100      8.600              12
# 4                 0      20700      7.000               8
# 5                 7      16920      9.175              41
# 6                 0      12600      7.500              10
# 7                15      14400      9.250              96
# 8                 1      13500      9.150               9
# 9                 2      20700      9.200              33
#
# [10 rows x 22 columns]

# %% [markdown]
# # trailer & isbn 추가

# %%
books = books.join(isbns, on = ['book_id'], how='left_outer')

# %%
books.orderBy(col('main_category').asc(), col('sub_category').asc()).limit(10).toPandas()
# Out:
#     book_id main_category sub_category                 book_title  \
# 0  10652913      가정/생활/요리        결혼/가족          우리 부부 어디서 잘못된 걸까?
# 1   7170355      가정/생활/요리        결혼/가족                   프랑스 아이처럼
# 2  16894194      가정/생활/요리        결혼/가족   별난 내과의사가 알려주는 정력을 키우는 방법
# 3   7170355      가정/생활/요리        결혼/가족                   프랑스 아이처럼
# 4   7170355      가정/생활/요리        결혼/가족                   프랑스 아이처럼
# 5    118719      가정/생활/요리        결혼/가족  그 남자가 원하는 여자 그 여자가 원하는 남자
# 6  18059178      가정/생활/요리        결혼/가족      우리가 사랑할 때 물어야 할 여덟 가지
# 7   7916309      가정/생활/요리        결혼/가족                      회복탄력성
# 8   7170355      가정/생활/요리        결혼/가족                   프랑스 아이처럼
# 9  11823851      가정/생활/요리        결혼/가족             행복한 결혼을 위한 7원칙
#
#                                 book_author publisher publish_date  \
# 0                                       이병준      영진닷컴   2016.06.03
# 1                                  파멜라 드러커맨      북하이브   2013.03.20
# 2                                       조왕기        린쓰   2020.10.30
# 3                                  파멜라 드러커맨      북하이브   2013.03.20
# 4                                  파멜라 드러커맨      북하이브   2013.03.20
# 5                                       김성묵       김영사   2003.01.10
# 6  존 가트맨 줄리 슈워츠 가트맨 더글러스 에이브럼스 레이철 칼턴 에이브럼스     해냄출판사   2021.03.05
# 7                                       최성애     해냄출판사   2014.07.28
# 8                                  파멜라 드러커맨      북하이브   2013.03.20
# 9                                존 가트맨 낸 실버      문학사상   2017.03.22
#
#    aladin_price  aladin_star  aladin_review  ...  yes24_star  yes24_review  \
# 0         11700          0.0              0  ...        10.0             1
# 1         13500          8.9            100  ...         8.6            88
# 2         10800          8.9              9  ...         8.7             8
# 3         13500          8.9            100  ...         8.6            88
# 4         13500          8.9            100  ...         8.6            88
# 5          8910          7.8             11  ...         8.2            11
# 6         14850          9.7             26  ...         9.6            24
# 7         14850          9.0             30  ...         9.3            49
# 8         13500          8.9            100  ...         8.6            88
# 9         13500          0.0              0  ...        10.0             1
#
#    interpark_price  interpark_star  interpark_review  min price  avg stars  \
# 0            11700             0.0                 0      11700      5.000
# 1            13500             8.6                25      13500      8.925
# 2            10800             8.0                 2      10800      8.900
# 3            13500             8.6                25      13500      8.925
# 4            13500             8.6                25      13500      8.925
# 5             8910             8.5                 7       8910      8.325
# 6            14850             9.1                 7      14850      9.600
# 7            14850             9.3                34      14850      9.400
# 8            13500             8.6                25      13500      8.925
# 9            13500             8.0                 1      13500      7.000
#
#    num of reviews       book_isbn  \
# 0               1            None
# 1             216   9788928615360
# 2              22   9791196054984
# 3             216   9788928615360
# 4             216   9788928615360
# 5              30   9788934912088
# 6              71   9788965743408
# 7             137   9788965744528
# 8             216   9788928615360
# 9               2   9788970129396
#
#                                         book_trailer
# 0                                               None
# 1  나와 아이가 조금 더 행복해지는 프랑스식 육아법!\r\n\r\n아이, 엄마, 가족이...
# 2  정력이라고 하면 좀 낯뜨거운 거 같다고?\r\n나도 몰랐던 내 몸의 기능이 되살아난...
# 3  나와 아이가 조금 더 행복해지는 프랑스식 육아법!\r\n\r\n아이, 엄마, 가족이...
# 4  나와 아이가 조금 더 행복해지는 프랑스식 육아법!\r\n\r\n아이, 엄마, 가족이...
# 5  교회 사역장로 및 한국가정사역학회 부회장, 두란노아버지학교운동본부장으로 활동하며 가...
# 6  아마존 결혼 · 가정 분야 1위!\r\n\r\n2019 노틸러스 북어워드 ‘인간관계...
# 7  누군가를 돌보고 가르치는 사람들에게 전하는 스트레스 조절과 관계의 기술!\r\n\r...
# 8  나와 아이가 조금 더 행복해지는 프랑스식 육아법!\r\n\r\n아이, 엄마, 가족이...
# 9  존 가트맨 박사는 수십 년 동안 수많은 부부들을 연구하는 과정에서 행복한 부부와 이...
#
# [10 rows x 24 columns]

# %% [markdown]
# # 중복제거

# %%
books = books.dropDuplicates(['book_id'])

# %%
books.limit(10).toPandas()
# Out:
#    book_id main_category sub_category  \
# 0   182678           어린이      초등1~2학년
# 1  2084345         역사/문화      역사/문화일반
# 2  6050510           어린이      초등5~6학년
# 3  6055863            소설        고전/문학
# 4  6348922            인문          종교학
# 5  6597874         취미/레저         옷만들기
# 6  6793587          해외도서        취미/여행
# 7  6822225           청소년       청소년 문학
# 8  7820011       예술/대중문화           사진
# 9  8882146         역사/문화      역사/문화일반
#
#                                       book_title  book_author  \
# 0                                       종이 봉지 공주        버트 먼치
# 1                                          총 균 쇠    재레드 다이아몬드
# 2                                     불량한 자전거 여행           남중
# 3                                           1Q84     무라카미 하루키
# 4                                         종교의 미래        하비 콕스
# 5                             초보자를 위한 친환경 가구 만들기          우상연
# 6  Pantone Postcard Box: 100 Postcards (Novelty)  Pantone INC
# 7                                            방관자      제임스 프렐러
# 8                                      가문비나무의 노래      마틴 슐레스케
# 9                                       역사란 무엇인가       에드워드 카
#
#               publisher publish_date  aladin_price  aladin_star  \
# 0                   비룡소   2008.07.18          9900          9.2
# 1                 문학사상사   2005.12.19         25200          9.0
# 2                    창비   2009.07.28          9720          9.6
# 3                  문학동네   2009.09.08         13320          8.6
# 4                 문예출판사   2010.08.25         15300          9.1
# 5                 북하우스엔   2011.03.19         18000          8.2
# 6  Chronicle Books (CA)   2011.06.22         16500          0.0
# 7                   미래인   2012.03.05          8550          9.2
# 8                  니케북스   2014.07.10         13500         10.0
# 9                    까치   2015.03.16         10800          9.2
#
#    aladin_review  ...  yes24_star  yes24_review  interpark_price  \
# 0            131  ...         9.0            76             9900
# 1            301  ...         9.2           241            25200
# 2             92  ...         9.5            79             9720
# 3            327  ...         8.7           130            13320
# 4             11  ...         8.4            14            15300
# 5             20  ...         8.6             9            18000
# 6              0  ...         9.2            12            17500
# 7             29  ...         8.8            43             8550
# 8              5  ...         9.3            17            13500
# 9             68  ...         8.7            35            10800
#
#    interpark_star  interpark_review  min price  avg stars  num of reviews  \
# 0             9.2                56       9900      9.250             264
# 1             9.2               134      25200      9.125             677
# 2             9.8                22       9720      9.600             196
# 3             9.2               203      13320      9.050             692
# 4             8.9                10      15300      8.800              42
# 5             9.3                10      18000      8.600              42
# 6             0.0                 0      16500      4.175              13
# 7             9.4                27       8550      9.300             100
# 8             9.4                 6      13500      9.650              28
# 9             8.8                 2      10800      9.050             106
#
#         book_isbn                                       book_trailer
# 0   9788949110479  왕자를 구한 공주의 운명은?\r\n\r\n안데르센의 동화 「돼지치기 소년」을 페미니...
# 1   9788970127248  왜 어떤 민족들은 다른 민족들의 정복과 지배의 대상으로 전락하고 말았는가. 왜 원주...
# 2   9788936442507  뜨거운 여름 1,100킬로 자전거 여행 한 소년이 그 길에서 준비한 '불량한 출발'...
# 3   9788954608657  당신의 하늘에는 몇 개의 달이 떠 있습니까?\r\n\r\n무라카미 하루키가 <어둠의...
# 4   9788931006810  세계적인 종교학자 하비콕스가 내놓은 그리스도교의 미래와 전망\r\n\r\n예수의 시...
# 5   9788956055152  친절한 가구 제작 안내서\r\n\r\n공구 사용법부터 가구 제작법까지 우리집 목공 ...
# 6   9780811877541  WITH A PALETTE DRAWN FROM THE SYSTEMS OF PANTO...
# 7   9788983946966  방관자는 다음 피해자인가?\r\n\r\n가해자와 피해자 사이에서 갈등하는 방관자의 ...
# 8   9788994361147  독일의 바이올린 장인 마틴 슐레스케가 작업장에서 길어 올린 365개의 맑은 생각과 ...
# 9   9788972915812  역사란 ‘과거와 현재의 대화’ 또는 ‘과거의 사실과 현재의 역사가의 대화’라는 것은...
#
# [10 rows x 24 columns]

# %% [markdown]
# # 플랫폼별 가격, 별점, 리뷰 평균

# %%
books_platform = books.agg(avg("aladin_price").alias('avg_aladin_price'), avg("aladin_star").alias('avg_aladin_star'), 
             avg("aladin_review").alias('avg_aladin_review'), avg("kyobo_price").alias('avg_kyobo_price'),
             avg("kyobo_star").alias('avg_kyobo_star'), avg("kyobo_review").alias('avg_kyobo_review'),
             avg("yes24_price").alias('avg_yes24_price'), avg("yes24_star").alias('avg_yes24_star'),
             avg("yes24_review").alias('avg_yes24_review'), avg("interpark_price").alias('avg_interpark_price'),
             avg("interpark_star").alias('avg_interpark_star'), avg("interpark_review").alias('avg_interpark_review'))
books_platform.limit(10).toPandas()
# Out:
#    avg_aladin_price  avg_aladin_star  avg_aladin_review  avg_kyobo_price  \
# 0      15371.036493         8.269974          27.032606     15357.971281
#
#    avg_kyobo_star  avg_kyobo_review  avg_yes24_price  avg_yes24_star  \
# 0        9.533902          4.541892     17011.343122        9.358076
#
#    avg_yes24_review  avg_interpark_price  avg_interpark_star  \
# 0         27.013064         15357.971281            6.454394
#
#    avg_interpark_review
# 0               7.54146

# %%
books_platform.coalesce(1).write.format("com.databricks.spark.csv").option("header", "true").save("/home/hadoop/venv/books_platform.csv")

# %% [markdown]
# # main category별 별점, 가격, 리뷰개수 평균

# %% [markdown]
# ### 별점 평균

# %%
books_main_star = books.groupby(books['main_category']).agg({'aladin_star':'mean', 'kyobo_star': 'mean', 'yes24_star': 'mean', 
                                                        'interpark_star': 'mean'})

books_main_star = books_main_star.withColumn("avg stars", (col('avg(aladin_star)') + col('avg(kyobo_star)') + col('avg(yes24_star)') + col('avg(interpark_star)'))/4)
books_main_star.orderBy(col('avg stars').desc()).toPandas()
# Out:
#    main_category  avg(aladin_star)  avg(kyobo_star)  avg(yes24_star)  \
# 0            어린이          9.186822         9.719380         9.603618
# 1             소설          8.815077         9.524000         9.174154
# 2           자기계발          8.783333         9.452339         9.227485
# 3          경제/경영          8.757552         9.422396         9.339583
# 4             유아          8.601553         9.634783         9.535404
# 5       가정/생활/요리          8.987841         9.511166         9.501489
# 6             인문          8.673541         9.486770         9.209533
# 7            청소년          8.429797         9.574041         9.385553
# 8          시/에세이          8.909859         9.483380         9.250986
# 9             건강          8.457143         9.423292         9.311180
# 10         여행/지도          8.457711         9.457711         9.291542
# 11         역사/문화          8.343434         9.552525         9.331313
# 12            사회          8.361917         9.464767         9.205959
# 13       예술/대중문화          8.298748         9.542039         9.245438
# 14            종교          8.527000         9.543667         9.267000
# 15        국어/외국어          7.727094         9.516010         9.422167
# 16         취미/레저          8.035247         9.452313         9.288676
# 17         과학/공학          7.452571         9.503571         9.313429
# 18        컴퓨터/IT          8.116981         9.493711         9.508491
# 19        학습/참고서          6.500855         9.744872         9.623077
# 20            만화          8.432117         9.745401         9.582482
# 21            사전          7.067241         9.431897         8.850862
# 22          해외도서          6.727148         9.411684         9.292440
# 23            잡지          6.514286         9.600000         9.696429
# 24        취업/수험서          6.217500         9.741250         9.830625
#
#     avg(interpark_star)  avg stars
# 0              8.128682   9.159625
# 1              8.222462   8.933923
# 2              8.135673   8.899708
# 3              8.046615   8.891536
# 4              7.593789   8.841382
# 5              7.141191   8.785422
# 6              7.416148   8.696498
# 7              7.370429   8.689955
# 8              6.959296   8.650880
# 9              7.265528   8.614286
# 10             7.126866   8.583458
# 11             6.750505   8.494444
# 12             6.290674   8.330829
# 13             6.047585   8.283453
# 14             5.474667   8.203083
# 15             5.943596   8.152217
# 16             5.781340   8.139394
# 17             6.184571   8.113536
# 18             5.294340   8.103381
# 19             6.226923   8.023932
# 20             4.251241   8.002810
# 21             5.426724   7.694181
# 22             4.235052   7.416581
# 23             3.489286   7.325000
# 24             2.986875   7.194063

# %% [markdown]
# ### 가격 평균

# %%
books_main_price = books.groupby(books['main_category']).agg({'aladin_price':'mean', 
                                                              'kyobo_price': 'mean', 
                                                              'yes24_price': 'mean', 
                                                              'interpark_price': 'mean'})

books_main_price = books_main_price.withColumn("avg price", 
                                               (col('avg(aladin_price)') + col('avg(kyobo_price)') 
                                                + col('avg(yes24_price)') + col('avg(interpark_price)'))/4)
books_main_price.orderBy(col('avg price').desc()).toPandas()
# Out:
#    main_category  avg(aladin_price)  avg(kyobo_price)  avg(interpark_price)  \
# 0             사전       32003.534483      31939.310345          31939.310345
# 1         취업/수험서       22731.875000      22623.812500          22623.812500
# 2         컴퓨터/IT       21640.314465      21625.314465          21625.314465
# 3          과학/공학       21199.585714      21093.657143          21093.657143
# 4          역사/문화       19174.646465      19112.727273          19112.727273
# 5             사회       17582.331606      17515.595855          17515.595855
# 6             잡지       17356.785714      17246.071429          17246.071429
# 7          여행/지도       16841.044776      16836.567164          16836.567164
# 8        예술/대중문화       16771.556351      16775.330948          16775.330948
# 9             인문       16520.914397      16536.031128          16536.031128
# 10         경제/경영       16097.786458      16082.473958          16082.473958
# 11      가정/생활/요리       15905.384615      15883.325062          15883.325062
# 12        국어/외국어       15120.369458      15101.527094          15101.527094
# 13            건강       14943.198758      14906.863354          14906.863354
# 14         취미/레저       14888.915470      14902.041467          14902.041467
# 15            종교       14573.766667      14536.900000          14536.900000
# 16            소설       14560.153846      14573.076923          14573.076923
# 17          해외도서       13418.419244      13425.120275          13425.120275
# 18          자기계발       13811.140351      13828.040936          13828.040936
# 19           청소년       13569.774266      13564.582393          13564.582393
# 20         시/에세이       13145.971831      13145.549296          13145.549296
# 21        학습/참고서       12207.478632      12207.478632          12207.478632
# 22            유아       11088.260870      11144.875776          11144.875776
# 23           어린이       10887.441860      10887.441860          10887.441860
# 24            만화        9164.058394       9190.408759           9190.408759
#
#     avg(yes24_price)     avg price
# 0       34956.034483  32709.547414
# 1       25118.125000  23274.406250
# 2       23826.729560  22179.418239
# 3       22788.714286  21543.903571
# 4       21208.080808  19652.045455
# 5       19253.886010  17966.852332
# 6       18857.142857  17676.517857
# 7       18601.990050  17279.042289
# 8       18546.475850  17217.173524
# 9       18198.832685  16947.952335
# 10      17839.843750  16525.644531
# 11      17640.645161  16328.169975
# 12      16570.911330  15473.583744
# 13      16518.664596  15318.897516
# 14      16442.519936  15283.879585
# 15      16116.333333  14940.975000
# 16      15275.938462  14745.561538
# 17      17889.037801  14539.424399
# 18      15318.421053  14196.410819
# 19      14909.029345  13901.992099
# 20      14563.098592  13500.042254
# 21      13547.008547  12542.361111
# 22      12690.527950  11517.135093
# 23      12097.157623  11189.870801
# 24      10209.343066   9438.554745

# %% [markdown]
# ### 리뷰 평균

# %%
books_main_review = books.groupby(books['main_category']).agg({'aladin_review':'mean', 'kyobo_review': 'mean', 'yes24_review': 'mean', 
                                                        'interpark_review': 'mean'})

books_main_review = books_main_review.withColumn("avg review", (col('avg(aladin_review)') + col('avg(kyobo_review)') + col('avg(yes24_review)') + col('avg(interpark_review)'))/4)
books_main_review.orderBy(col('avg review').desc()).toPandas()
# Out:
#    main_category  avg(interpark_review)  avg(aladin_review)  \
# 0             소설              34.886154          148.603077
# 1           자기계발              15.029240           47.713450
# 2            어린이              15.248062           37.134367
# 3          역사/문화               9.383838           45.181818
# 4          경제/경영               9.619792           36.041667
# 5             인문               9.324903           40.498054
# 6             유아              15.844720           29.605590
# 7          시/에세이               8.369014           33.500000
# 8             사회               6.634715           36.787565
# 9       가정/생활/요리               8.392060           25.146402
# 10         여행/지도               7.203980           22.218905
# 11           청소년               7.568849           17.352144
# 12        학습/참고서               4.666667            7.700855
# 13            건강               6.037267           17.680124
# 14         과학/공학               4.692857           17.417143
# 15            만화               1.846715           15.125547
# 16        국어/외국어               3.768473           12.019704
# 17       예술/대중문화               3.325581           16.347048
# 18        컴퓨터/IT               2.298742           11.666667
# 19            종교               4.243333           13.020000
# 20         취미/레저               2.955343           10.606061
# 21        취업/수험서               1.756250            7.393750
# 22          해외도서               2.718213            6.841924
# 23            잡지               2.750000            6.535714
# 24            사전               2.456897            6.620690
#
#     avg(yes24_review)  avg(kyobo_review)  avg review
# 0           98.600000           9.858462   72.986923
# 1           52.956140          12.116959   31.953947
# 2           46.509044           4.211886   25.775840
# 3           37.959596           3.606061   24.032828
# 4           42.161458           7.385417   23.802083
# 5           34.377432           6.025292   22.556420
# 6           40.826087           3.714286   22.497671
# 7           24.381690           6.588732   18.209859
# 8           23.279793           4.323834   17.756477
# 9           31.183623           4.516129   17.309553
# 10          21.437811           5.830846   14.172886
# 11          20.485327           5.525959   12.733070
# 12          35.970085           2.538462   12.719017
# 13          19.332298           5.546584   12.149068
# 14          17.065714           4.752857   10.982143
# 15          19.421898           2.328467    9.680657
# 16          19.950739           2.177340    9.479064
# 17          14.509839           2.352415    9.133721
# 18          15.632075           2.591195    8.047170
# 19          10.773333           2.683333    7.680000
# 20          12.384370           2.917065    7.215710
# 21          16.706250           2.156250    7.003125
# 22          11.556701           0.982818    5.524914
# 23           7.392857           3.142857    4.955357
# 24           6.155172           1.189655    4.105603

# %%
books_main_star.coalesce(1).write.format("com.databricks.spark.csv") \
            .option("header", "true") \
            .save("/home/hadoop/venv/books_main_star.csv")

books_main_price.coalesce(1).write.format("com.databricks.spark.csv") \
            .option("header", "true") \
            .save("/home/hadoop/venv/books_main_price.csv")

books_main_review.coalesce(1).write.format("com.databricks.spark.csv") \
            .option("header", "true") \
            .save("/home/hadoop/venv/books_main_review.csv")

# %% [markdown]
# # sub category별 별점, 가격, 리뷰개수 평균

# %% [markdown]
# ### 별점 평균

# %%
books_sub_star = books.groupby(books['sub_category']).agg({'aladin_star':'mean', 'kyobo_star': 'mean', 'yes24_star': 'mean', 
                                                        'interpark_star': 'mean'})

books_sub_star = books_sub_star.withColumn("avg stars", (col('avg(aladin_star)') + col('avg(kyobo_star)') + col('avg(yes24_star)') + col('avg(interpark_star)'))/4)
books_sub_star.limit(10).toPandas()
# Out:
#   sub_category  avg(aladin_star)  avg(kyobo_star)  avg(yes24_star)  \
# 0     쉽게 읽는 과학          9.233333         9.566667         9.312121
# 1         집/살림          8.693902         9.385366         9.378049
# 2      천문/지구과학          8.644156         9.648052         9.329870
# 3          한국사          8.273529         9.558824         9.320588
# 4           낚시          3.666667         8.866667         9.233333
# 5           골프          9.440000         9.260000         9.260000
# 6           불교          8.186154         9.509231         9.296923
# 7          일본어          8.402222         9.592222         9.393333
# 8          서양사          9.100000         9.850000         9.200000
# 9         취미기타          8.820513         9.596154         9.564103
#
#    avg(interpark_star)  avg stars
# 0             7.790909   8.975758
# 1             5.606098   8.265854
# 2             6.876623   8.624675
# 3             6.672059   8.456250
# 4             5.066667   6.708333
# 5             7.260000   8.805000
# 6             5.275385   8.066923
# 7             6.725556   8.528333
# 8             8.300000   9.112500
# 9             6.843590   8.706090

# %% [markdown]
# ### 가격 평균

# %%
books_sub_price = books.groupby(books['sub_category']).agg({'aladin_price':'mean', 'kyobo_price': 'mean', 'yes24_price': 'mean', 
                                                        'interpark_price': 'mean'})

books_sub_price = books_sub_price.withColumn("avg price", (col('avg(aladin_price)') + col('avg(kyobo_price)') + col('avg(yes24_price)') + col('avg(interpark_price)'))/4)
books_sub_price.limit(10).toPandas()
# Out:
#   sub_category  avg(aladin_price)  avg(kyobo_price)  avg(interpark_price)  \
# 0     쉽게 읽는 과학       18409.090909      18409.090909          18409.090909
# 1         집/살림       17383.170732      17333.780488          17333.780488
# 2      천문/지구과학       17099.220779      17091.428571          17091.428571
# 3          한국사       17940.000000      17888.823529          17888.823529
# 4           낚시       12900.000000      12900.000000          12900.000000
# 5           골프       15930.000000      15480.000000          15480.000000
# 6           불교       13044.923077      13033.384615          13033.384615
# 7          일본어       14998.444444      14998.444444          14998.444444
# 8          서양사       26100.000000      26100.000000          26100.000000
# 9         취미기타       13564.487179      13872.948718          13872.948718
#
#    avg(yes24_price)     avg price
# 0      20454.545455  18920.454545
# 1      19259.756098  17827.621951
# 2      18955.844156  17559.480519
# 3      19835.294118  18388.235294
# 4      14333.333333  13258.333333
# 5      17200.000000  16022.500000
# 6      14396.923077  13377.153846
# 7      16493.222222  15372.138889
# 8      29000.000000  26825.000000
# 9      16011.538462  14330.480769

# %% [markdown]
# ### 리뷰 평균

# %%
books_sub_review = books.groupby(books['sub_category']).agg({'aladin_review':'mean', 'kyobo_review': 'mean', 'yes24_review': 'mean', 
                                                        'interpark_review': 'mean'})

books_sub_review = books_sub_review.withColumn("avg review", (col('avg(aladin_review)') + col('avg(kyobo_review)') + col('avg(yes24_review)') + col('avg(interpark_review)'))/4)
books_sub_review.limit(10).toPandas()
# Out:
#   sub_category  avg(interpark_review)  avg(aladin_review)  avg(yes24_review)  \
# 0     쉽게 읽는 과학               7.424242           24.151515          27.030303
# 1         집/살림               3.646341           12.939024          16.024390
# 2      천문/지구과학               5.818182           22.701299          20.831169
# 3          한국사               5.705882           25.867647          27.411765
# 4           낚시               1.333333            0.888889           2.333333
# 5           골프               1.600000            2.800000           6.400000
# 6           불교               4.723077           17.400000           9.800000
# 7          일본어               4.344444           12.588889          14.522222
# 8          서양사               9.500000           17.000000          20.500000
# 9         취미기타               5.794872           12.948718          21.820513
#
#    avg(kyobo_review)  avg review
# 0           6.636364   16.310606
# 1           3.914634    9.131098
# 2           4.753247   13.525974
# 3           3.558824   15.636029
# 4           0.333333    1.222222
# 5           1.600000    3.100000
# 6           1.846154    8.442308
# 7           2.077778    8.383333
# 8           5.000000   13.000000
# 9           5.730769   11.573718

# %%
books_sub_star.coalesce(1).write.format("com.databricks.spark.csv") \
            .option("header", "true") \
            .save("/home/hadoop/venv/books_sub_star.csv")

books_sub_price.coalesce(1).write.format("com.databricks.spark.csv") \
            .option("header", "true") \
            .save("/home/hadoop/venv/books_sub_price.csv")

books_sub_review.coalesce(1).write.format("com.databricks.spark.csv") \
            .option("header", "true") \
            .save("/home/hadoop/venv/books_sub_review.csv")

# %% [markdown]
# # 기본 책 정보 csv 저장

# %%
books.coalesce(1).write.format("com.databricks.spark.csv").option("header", "true").save("/home/hadoop/venv/book_info.csv")
